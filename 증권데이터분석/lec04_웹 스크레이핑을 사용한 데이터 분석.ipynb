# %% [markdown]
# # 4. 웹 스크레이핑을 사용한 데이터 분석

# %% [markdown]
# ## 4.1 팬더스로 상장법인 목록 읽기
# - 증권 데이터 분석을 하려면 종목코드를 알아야 한다.
# - 전체 종목코드가 있어야 종목별로 급등 순위, 시가총액 순위 등의 통계를 낼 수 있기 때문이다.

# %% [markdown]
# ### 4.1.2 read_html() 함수로 파일 읽기
# - read_html() 함수는 인수로 받은 경로의 HTML 파일 내부에 존재하는 TABLE 태그를 분석하여 데이터프레임으로 변환해준다.
# - read_html() 함수는 결과값으로 데이터프레임 객체를 원소로 갖는 리스트를 반환한다.

# %%
import pandas as pd
krx_list = pd.read_html('./data/상장법인목록.xls')
krx_list[0]
# Out:
#             회사명    종목코드                         업종  \
# 0        스튜디오미르  408900  영화, 비디오물, 방송프로그램 제작 및 배급업
# 1         삼기이브이  419050              자동차 신품 부품 제조업
# 2     코오롱모빌리티그룹  450140                    자동차 판매업
# 3           오브젠  417860             소프트웨어 개발 및 공급업
# 4         미래반도체  254490                  기타 전문 도매업
# ...         ...     ...                        ...
# 2571     CJ대한통운     120                  도로 화물 운송업
# 2572      메리츠화재      60                        보험업
# 2573         경방      50                     종합 소매업
# 2574      유수홀딩스     700        회사 본부 및 경영 컨설팅 서비스업
# 2575   한진중공업홀딩스    3480          연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                              애니메이션 제작  2023-02-07  12월
# 1                                 배터리(이차전지) 부품 (엔드플레이트)  2023-02-03  12월
# 2                                        수입자동차 유통 및 정비업  2023-01-31  12월
# ...

# %% [markdown]
# - 자세히 보면 엑셀 프로그램에서 여섯 자리던 종목코드가 앞자리 0이 사라져있다. map() 함수를 사용해 이를 보정해보자.

# %%
krx_list[0].종목코드 = krx_list[0].종목코드.map('{:06d}'.format)
krx_list[0]
# Out:
#             회사명    종목코드                         업종  \
# 0        스튜디오미르  408900  영화, 비디오물, 방송프로그램 제작 및 배급업
# 1         삼기이브이  419050              자동차 신품 부품 제조업
# 2     코오롱모빌리티그룹  450140                    자동차 판매업
# 3           오브젠  417860             소프트웨어 개발 및 공급업
# 4         미래반도체  254490                  기타 전문 도매업
# ...         ...     ...                        ...
# 2571     CJ대한통운  000120                  도로 화물 운송업
# 2572      메리츠화재  000060                        보험업
# 2573         경방  000050                     종합 소매업
# 2574      유수홀딩스  000700        회사 본부 및 경영 컨설팅 서비스업
# 2575   한진중공업홀딩스  003480          연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                              애니메이션 제작  2023-02-07  12월
# 1                                 배터리(이차전지) 부품 (엔드플레이트)  2023-02-03  12월
# 2                                        수입자동차 유통 및 정비업  2023-01-31  12월
# ...

# %% [markdown]
# - format() 함수를 인수로 넘겨주었는데, {:06d}는 여섯 자리 숫자 형식으로 표현하되 빈 앞 자리를 0으로 채우라는 뜻이다.format
# - read_html() 함수는 로컬 드라이브에 있는 파일뿐 아니라, URL을 이용해 인터넷 상 파일도 읽을 수 있다.
# - 다음은 인터넷에 있는 '상장법인목록.xls'파일을 바로 읽어오는 예다.

# %%
df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13')[0]
df['종목코드'] = df['종목코드'].map('{:06d}'.format)
df = df.sort_values(by='종목코드')
df
# Out:
#              회사명    종목코드                      업종  \
# 32          동화약품  000020                 의약품 제조업
# 340        KR모터스  000040          그외 기타 운송장비 제조업
# 1614          경방  000050                  종합 소매업
# 1638       메리츠화재  000060                     보험업
# 47         삼양홀딩스  000070                  기타 금융업
# ...          ...     ...                     ...
# 1698         JTC  950170                  종합 소매업
# 2048         미투젠  950190          소프트웨어 개발 및 공급업
# 2072         소마젠  950200  그외 기타 전문, 과학 및 기술 서비스업
# 1980  프레스티지바이오파마  950210         자연과학 및 공학 연구개발업
# 451        네오이뮨텍  950220         자연과학 및 공학 연구개발업
#
#                                            주요제품         상장일  결산월  \
# 32                                의약품 제조,판매,수출입  1976-03-24  12월
# 340                             이륜차(오토바이) 제조,도매  1976-05-25  12월
# 1614  섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 1638                           손해보험(화재,해상,운송보험)  1956-07-02  12월
# ...

# %% [markdown]
# ## 4.2 HTML 익히기

# %% [markdown]
# ### 4.2.1 HTML 기본 구조
# - HyperText : 다른 문서를 연결하는 텍스트
# - 마크업 : 텍스트가 화면에서 어떻게 보여야 하는지 정의하는 기법

# %% [markdown]
# ### 4.2.2 HTML 주요 태그
# - 태그는 속성이라는 추가 정보를 지닐 수 있다.
# - 하이퍼링크를 정의하는 <a> 태그는 링크 목적지를 나타내는 href 속성을 가진다.

# %% [markdown]
# ### 4.2.3 HTML 예시
# - HTML 파일은 기본적으로 <html> 태그 안에 <head> 태그와 <body>태그를 갖는다.
# - <head> 태그는 HTML 페이지 정보를 제공한다.
# - 웹 브라우저에서 보이는 부분은 <body> 태그 내부에 있다.

# %% [markdown]
# ## 4.3 웹에서 일별 시세 구하기
# - 네이버 금융에 접속하면 한국거래소에 상장된 종목의 일별 시세를 확인할 수 있다.

# %% [markdown]
# ### 4.3.1 네이버 금융 일별 시세 분석하기

# %% [markdown]
# ### 4.3.2 소스 코드에서 링크 주소 검색하기
# - 웹 페이지로부터 HTML 소스 코드를 읽어와 맨 뒤 페이지가 실제로 몇 페이지인지 알아내는 과정을 웹 스크레이핑 파이썬 라이브러리인 뷰티풀 수프로 진행해보자.

# %% [markdown]
# ## 4.4 뷰티풀 수프로 일별 시세 읽어오기
# - 뷰티플 수프는 HTML, XML 페이지로부터 데이터를 추출하는 파이썬 라이브러리이다.

# %% [markdown]
# ### 4.4.2 find_all() 함수와 find() 함수 비교
# - find_all() 함수는 문서 전체를 대상으로 조건에 맞는 모든 태그를 찾는다.
# - find() 함수를 사용하면 더 간편하다.
# - 아무것도 못 찾으면 find_all() 함수는 빈 리스트를, find() 함수는 None을 반환한다.

# %% [markdown]
# ### 4.4.3 맨 뒤 페이지 숫자 구하기
# - 먼저 뷰티플 수프를 이용하여 네이버 금융에서 셀트리온의 맨 뒤 페이지 숫자를 구해보자.
# - 네이버 금융 웹 서버는 브라우저 정보가 없는 웹 스크레이핑을 차단하기 때문에, 웹 스크레이핑을 하기 위해서는 requests 라이브러리를 이용해 HTTP 패킷 헤더에 브라우저 정보를 추가하여 웹 페이지를 요청해야 한다.
# - requests가 설치
